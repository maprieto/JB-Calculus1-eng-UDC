# %% [markdown]
# # Bulletin III: Differential Calculus of Functions of One Variable
#
# ## Basic exercises
#
# **<FONT SIZE=4>[1]</font>** Let $f$ be the function given by $f(x)=5x^2.$
#
# 1. Use the definition of the derivative to show that $f'(x)=10x.$
# 2. Compute the equation of the tangent line to the graph of $f$ at $\displaystyle{x=\frac12}.$

# %% [markdown]
# **<FONT SIZE=4>[2]</font>**
# Let $f : \mathbb{R} \longrightarrow \mathbb{R}$ be given by:
#
# $$
# f(x) =
# \begin{cases}
# 2x - 1 & \quad \text{if } x \leq -1 \\
# (x+1)^3 + 2x & \quad \text{if } x > -1
# \end{cases}
# $$
#
# Determine whether it is differentiable at $x = -1$.

# %% [markdown]
# **<FONT SIZE=4>[3]</font>**
# Let $f$ be the function given by
#
# $$
# f(x)=
# \begin{cases}
# \displaystyle{x+x^2 \sin\left(\frac{1}{x}\right)} & \text{if } x\neq 0 \\
# 0 & \text{if } x = 0
# \end{cases}
# $$
#
# 1. Obtain the expression of $f'(x)$ for $x\neq 0$.
# 2. Compute $f'(0)$ using the definition of the derivative; that is, as the limit of the difference quotient.
# 3. Check that the value obtained in part [3.2] does not coincide with the result of substituting $x=0$ into the expression found in [3.1]. Explain why these different results occur.

# %% [markdown]
# **<FONT SIZE=4>[4]</font>**
# Consider the function $f$ given by:
#
# $$
# f(x) =
# \begin{cases}
# \displaystyle{\frac{1-e^{-x}}{x}} & \quad \text{if } x \neq 0 \\
# 1 & \quad \text{if } x = 0
# \end{cases}
# $$
#
# 1. Compute $f'(x)$ at every point where it exists.
# 2. Compute $\displaystyle{\lim_{x\to -\infty}{f(x)}}$, $\displaystyle{\lim_{x\to \infty}{f(x)}}$, and the set $\textrm{Im}(f)$.

# %% [markdown]
# **<FONT SIZE=4>[5]</font>**
# Write the Newton-Raphson method to approximate $\sqrt[3]{2}$ starting from $x_0 = 1$. Compute the first two iterates.

# %% [markdown]
# **<FONT SIZE=4>[6]</font>**
# To approximate the value of the solution of the equation $x^3+2x-2=0$ in the interval $[-2,\, 2]$, we are going to use the Newton-Raphson method.
#
# 1. State the Newton-Raphson algorithm for this case.
# 2. Compute the first two iterations using that algorithm. To do this, use the value $x_0=0$ as the initial approximation.

# %% [markdown]
# **<FONT SIZE=4>[7]</font>**
# Let $f(x) = \displaystyle \arctan \left( \frac{\sin(x)}{1 + \cos(x)} \right )$. Compute the tangent line to the graph of $f$ at $x = 0$.

# %% [markdown]
# **<FONT SIZE=4>[8]</font>**
# Let the function $f$ be given by $f(x) = (4x+1)^{(2+ \sin(x^2))}$. Compute its derivative at any point.

# %% [markdown]
# **<FONT SIZE=4>[9]</font>**
# If we consider the function $f:\mathbb{R}\rightarrow \mathbb{R}$ given by
#
# $$
# f(x)=\displaystyle{\left\{ \begin{array}{ccl}
# \displaystyle{\frac{\sin^2(3x)}{3x^2}} & \text{if} & x\neq 0 \\
# \displaystyle{\frac{1}{3}} & \text{if} & x=0
# \end{array}
# \right.},
# $$
# choose the correct option:
#
# 1. $\displaystyle\lim_{x\to 0}f(x)=\frac{1}{3}$.
# 2. It is not possible to compute $\displaystyle{\lim_{x\to 0}{f(x)}}$.
# 3. $\displaystyle{\lim_{x\to 0}{f(x)}}=3$.
# 4. It is continuous on $\mathbb{R}$.

# %% [markdown]
# **<FONT SIZE=4>[10]</font>**
# Compute the values of $a$ and $b$ such that
#
# $$
# \displaystyle{\lim_{x\to 0}\frac{ax^2+bx+1-e^{2x}}{\sin(x^2)}=1}
# $$

# %% [markdown]
# **<FONT SIZE=4>[11]</font>**
# Let the function $f$ be given by $\displaystyle f(x) = \frac{1}{2} x |x|$. What is the class of $f$?

# %% [markdown]
# **<FONT SIZE=4>[12]</font>** We consider the function $f$ given by
#
# $$
# f(x)=
# \begin{cases}
# \sin(x) \, \qquad \text{if } x \in (-\infty,0) \\
# \arctan(x) \, \qquad \text{if } x \in [0,1] \\
# \pi x^3 / 4 \, \qquad \text{if } x \in (1,+\infty)
# \end{cases}
# $$
# 1. Sketch the graph of $f$.
# 2. Determine the class of $f$ on $\mathbb{R}$.
# 3. Compute, if possible, the tangent line to $f$ at the point $x_0 = 0$.
# 4. Determine a set of real numbers on which $f$ is of class $C^{\infty}$.

# %% [markdown]
# **<FONT SIZE=4>[13]</font>**
# Let $f$ be the function given by
#
# $$
# f(x)=
# \begin{cases}
# \sqrt{x} + 1 & \quad \text{if } x \in (0,1) \\
# \alpha x^2 + \beta x + 1 & \quad \text{if } x \in [1,2)
# \end{cases}
# $$
#
# 1. Determine $\alpha$ and $\beta$ so that $f$ is differentiable on $(0,2)$.
# 2. What conditions must $\alpha$ and $\beta$ satisfy so that $f$ has a relative minimum at the point $x=1$?

# %% [markdown]
# **<FONT SIZE=4>[14]</font>**
# Compute the relative extrema, and the absolute extrema if they exist, of the function defined on the interval
# $\left[-\frac{1}{2},\frac{3}{2}\right]$ by $f(x) = x^2 - 2|x| + 2$.

# %% [markdown]
# **<FONT SIZE=4>[15]</font>**
# Consider the function $f:\mathbb{R} \rightarrow \mathbb{R}$ given by $\displaystyle{f(x)=\frac{|x|}{e^{x-1}}}$.
#
# 1. Study the continuity and differentiability of the function.
# 2. Sketch the graph of $f$. To do this, compute its relative extrema, inflection points, and asymptotes. Also determine its interval(s) of concavity and/or convexity.
# 3. Determine the absolute extrema of $f$.

# %% [markdown]
# **<FONT SIZE=4>[16]</font>**
# Show that the equation $x^4-4x^3-1=0$ has a unique root in the interval $[4,5]$.
# State the Newton-Raphson method to solve the equation from the previous part. Starting from $x_0=4$, obtain the approximation $x_1$ by hand and the approximation $x_7$ using `Python`.

# %% [markdown]
# **<FONT SIZE=4>[17]</font>**
# On what interval is the function $f$ given by $f(x)=x^3e^x$ increasing? Is it concave or convex on that interval? Sketch its graph.

# %% [markdown]
# **<FONT SIZE=4>[18]</font>**
# Find the condition that $\lambda$ must satisfy so that the polynomial $x^4 + x^3 + \lambda x^2$ is concave on some interval. Determine that interval in terms of $\lambda$.

# %% [markdown]
# **<FONT SIZE=4>[19]</font>**
# Find a cubic polynomial with no local extrema but with an inflection point and a horizontal tangent at $P=(1,\,20)$.

# %% [markdown]
# **<FONT SIZE=4>[20]</font>**
# Sketch the graph of a function whose slope is always positive and increasing. Do you know any elementary function that is an example of this situation? <br> Sketch the graph of a function whose slope is always positive and decreasing. Do you know any elementary function that is an example of this situation?

# %% [markdown]
# **<FONT SIZE=4>[21]</font>**
# A rectangle whose base lies on the $x$-axis has its two upper vertices on the parabola $y = 12 - x^2$. What is the largest area that this rectangle can have? Indicate its dimensions.

# %% [markdown]
# **<FONT SIZE=4>[22]</font>**
# Knowing that $p(x)=5+(x+1)^2+3(x+1)^3$ is the third-order Taylor polynomial centered at $x_0=-1$ of a function $f$, compute $f(-1)$, $f'(-1)$, and $f''(-1)$. Justify your answer.

# %% [markdown]
# **<FONT SIZE=4>[23]</font>**
# We consider the function $f$ defined by $f(x)=\ln(1+x)$.
#
# 1. Compute the McLaurin polynomial (that is, the Taylor polynomial with $x_0=0$) of order two for $f$.
# 2. Use this polynomial to approximate the value of $\ln(1.1)$, bounding the error made.

# %% [markdown]
# **<FONT SIZE=4>[24]</font>**
# Construct the first-order Taylor polynomial, $p$, for the function $g(x)=\sin(x)$, centered at the point $x_0=\pi/2$.
#
# Now consider the function $f$ defined as follows:
#
# $$
# f(x)=
# \begin{cases}
# \sin(x) \quad & \quad \text{if } x \leq \pi/2 \\
# p(x) \quad & \quad \text{if } x > \pi/2
# \end{cases}
# $$
# where $p$ is the polynomial constructed in the previous part. What is the class of $f$ on $\mathbb{R}$?

# %% [markdown]
# **<FONT SIZE=4>[25]</font>**
# Determine the second-order Taylor polynomial of the function $f(x)=\arcsin(x)$ at the point $x_0=0$. <br> Use the previous polynomial to obtain, approximately, the angle whose sine is $\frac{1}{10}$.

# %% [markdown]
# **<FONT SIZE=4>[26]</font>**
# Let the function be given by
#
# $$
# \begin{array}{cccl}
# f: & \mathcal{D}om(f) \subset \mathbb{R} & \longrightarrow & \mathbb{R} \\
# & x & \rightsquigarrow & f(x)=\dfrac{x^2}{e^x}
# \end{array}
# $$
#
# 1. Compute the domain of $f$.
# 2. Compute the absolute extrema of $f$ on the interval $[0,10]$, first justifying their existence.
# 3. Compute the absolute extrema of $f$ on its domain.

# %% [markdown]
# ## Complementary exercises
#
# **<font SIZE=4>[1 C]</font>**
# If the tangent line to the graph of the function $y=f(x)$ at the point $(4,3)$ passes through the point $(0,2)$, compute the value of the function $f$ and its derivative at the point whose abscissa is $x=4$.

# %% [markdown]
# **<font SIZE=4>[2 C]</font>**
# Approximate the solution of $x^3-x-1=0$ in $[1.3,\,1.4]$ using the Newton-Raphson method, starting from $x_0=1$ and performing three iterations.

# %% [markdown]
# **<font SIZE=4>[3 C]</font>**
# Find the numbers $a$ and $b$ such that $\displaystyle{\lim_{x\to 0}{\frac{\sqrt{ax+b}-2}{x}}=1}$.

# %% [markdown]
# **<font SIZE=4>[4 C]</font>**
# Compute the limit:
#
# $$
# \displaystyle{\lim_{x\to 0}\dfrac{(1+x)^{\frac{1}{x}}-e}{x}}.
# $$

# %% [markdown]
# **<font SIZE=4>[5 C]</font>**
# Consider the function $f:\mathbb{R} \longrightarrow \mathbb{R}$ given by:
#
# $$
# f(x)=
# \begin{cases}
# \dfrac{1-\cos(x)}{x^2} & \text{if } x\neq 0 \\
# \lambda & \text{if } x=0
# \end{cases}
# $$
#
# 1. Compute the value of $\lambda$ for which $f$ is differentiable at $x=0$.
# 2. Compute $f''(0)$ for the value of $\lambda$ found in the previous part.

# %% [markdown]
# **<font SIZE=4>[6 C]</font>**
# Let $f:\mathbb{R}\to\mathbb{R}$ be defined by
#
# $$
# f(x)=
# \begin{cases}
# 1-\frac{x^2}{2} & \text{if } x<0 \\
# \cos(x) & \text{if } x\geq 0
# \end{cases}
# $$
#
# How many times is $f$ differentiable at $x_0=0$?

# %% [markdown]
# **<font SIZE=4>[7 C]</font>**
# Check that the function $F$, given by $F(x)=\dfrac{1}{4}x^2-\ln x$, has a relative minimum, $x_{\min}$, in the interval $(1,3)$.
# Use the bisection algorithm, starting from $a=1$ and $b=3$, to approximate $x_{\min}$ with an error smaller than $\frac{1}{7}$.

# %% [markdown]
# **<font SIZE=4>[8 C]</font>**
# We consider the equation $x e^{-x}=e^{-3}$.
#
# 1. Check that it has exactly two solutions in $\mathbb{R}$.
# 2. State the Newton-Raphson method starting from a point in the interval $[2,5]$. Compute $x_2$ starting from $x_0=2$.

# %% [markdown]
# **<font SIZE=4>[9 C]</font>**
# We wish to construct an arc that follows the curve given by $f(x)=\sqrt{1-x^2}$. To facilitate the construction, it is proposed to approximate this function by a second-order Taylor polynomial centered at $a=0$. Compute that polynomial and approximate $f(1)$.

# %% [markdown]
# **<font SIZE=4>[10 C]</font>**
# During coughing, the diameter of the trachea decreases. The velocity $v$ of the air in the trachea during coughing is related to the radius $r$ by the equation
#
# $$
# v = Ar^2(r_0-r), \qquad A>0
# $$
# where $r_0$ is the radius in the relaxed state.
#
# 1. Find the radius of the trachea when the velocity is maximal, as well as this velocity.
# 2. Justify the existence of a minimum. Compute it.

# %% [markdown]
# **<font SIZE=4>[11 C]</font>**
# Find the radius and height of a cylindrical soda can of volume $33$ cm$^3$ that minimizes the amount of material used in its construction (assume that the thickness of the material is uniform throughout the can and negligible).

# %% [markdown]
# **<font SIZE=4>[12 C]</font>**
# Let the real function $f$ be given by:
#
# $$
# f(x)=
# \begin{cases}
# \dfrac{\sin(x)}{x}-1 & \quad \text{if } x<0 \\
# x^3e^{-x^2} & \quad \text{if } x\geq 0
# \end{cases}
# $$
#
# 1. Study the differentiability of $f$ on $\mathbb{R}$.
# 2. Compute the second-order Taylor polynomial of $f$ in a neighborhood of $x_0=1$.
# 3. Determine, with justification, the absolute extrema of $f$ on $[0,+\infty)$.

# %% [markdown]
# **<font SIZE=4>[13 C]</font>**
# Let the function $f$ be given by:
#
# $$
# f(x)=
# \begin{cases}
# \dfrac{\sin(x)}{x} & \quad \text{if } x<0 \\
# 2-\cos(x) & \quad \text{if } x\geq 0
# \end{cases}
# $$
#
# 1. Study the continuity of $f$ on $\mathbb{R}$.
# 2. Determine, if it exists, $f'(0)$. If so, explain whether $f$ is of class one on $\mathbb{R}$.
# 3. Compute the second-degree Taylor polynomial of $f$ at $x=-\pi$.

# %% [markdown]
# **<font SIZE=4>[14 C]</font>**
# Let $f(x)=\sqrt{x+1}$.
#
# 1. Find the fourth-order Taylor polynomial of $f$ at $x=0$.
# 2. Approximate $\sqrt{1.02}$ with the second-degree Taylor polynomial and bound the error made.

# %% [markdown]
# **<font SIZE=4>[15 C]</font>**
# Obtain the McLaurin polynomial (Taylor, with $x_0=0$) of order less than or equal to $n$ for $f(x)=(1-x)^{\alpha}$, with $\alpha\in\mathbb{R}$.

# %% [markdown]
# **<font SIZE=4>[16 C]</font>**
# Construct the Taylor polynomial of degree less than or equal to $3$ for the function $f(x)=x^2-2x+1$ in a neighborhood of the point $x_0=1$.

# %% [markdown]
# **<font SIZE=4>[17 C]</font>**
# Determine the absolute extrema of the function $f(x)=|16-x^2|$ on the interval $[-5,8]$.

# %% [markdown]
# **<font SIZE=4>[18 C]</font>**
# We want to approximate a root of the equation $x^3-x^2+2=0$.
#
# 1. Justify the existence of roots of the function $f$ given by $f(x)=x^3-x^2+2$ in the interval $[-2,3]$.
# 2. Starting from $x_0=2$, compute $x_1$ using Newton's algorithm. Use two correct decimal places in your calculations.
